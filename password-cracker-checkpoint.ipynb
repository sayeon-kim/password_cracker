# %%
import random
import string

# %%
password = 'KimSaYeon'
min_len = 2
max_len = 10
# 비밀번호의 최대, 최소 자릿수를 지정해놓았다

def generate_word(length):
    result = ''
    x = ''.join(random.sample(string.ascii_letters + string.digits, k=length))
    return x

# 옛날 옛적 첫번째 세대가 태어났다
def generate_population(size, min_len, max_len):
    population = []
    for i in range(size):
        # generate words with balanced length
        length = i % (max_len - min_len + 1) + min_len
        population.append(generate_word(length))
    return population

print(generate_word(length=10))
pop = generate_population(size=100, min_len=min_len, max_len=max_len)
pop
# Out:
# BoKczk9v35
# ['We',
#  '6kM',
#  '4ps2',
#  '0V9NW',
#  '8ufSHI',
#  '5XIwdme',
#  'kuNeC9p1',
#  'm7uNkZ942',
#  'vRN6LDqiG2',
#  'WM',
#  '59D',
#  '2EFR',
#  'DKbmV',
#  '24wnD6',
#  'l34gJaR',
#  'T1soLA3q',
#  'DNHeK9M1a',
#  'd05zrlU1jR',
#  'I9',
#  'J1L',
#  'rP9c',
#  'bRxQc',
#  'MinkCU',
#  'MH7XE9P',
#  'P8s3YK2H',
#  'hUMltE7Jq',
#  'FZKwtuq24W',
#  'DX',
#  'VWC',
#  'RrSq',
#  'inbKL',
#  '1nj5cm',
#  'Q3U9Y7x',
#  'KMzwJ20T',
#  'QUtSHmiOw',
#  '4fgSp0CQHc',
#  'GI',
#  'bJX',
#  '7YzK',
#  '6yPiJ',
#  'K6Gdwz',
#  'yA2Uja0',
#  'A5HlBFgU',
#  'lVbxr1BJP',
#  'xX2lB8cKnb',
#  'uX',
#  'PWY',
#  'QU0n',
#  'nVMtI',
#  'XqlHTj',
#  'DaNXTsM',
#  'yPQIogcC',
#  'sWclS2qUH',
#  'NVpz1rXaEl',
#  'b5',
#  'KJB',
#  'fqRr',
#  'cDHTV',
#  'JExXt6',
#  's4Tudxc',
#  'A0evhXKE',
#  'Yd2ESATQl',
#  '8BRYwO2JXc',
#  'c2',
#  'oqC',
#  'kAIj',
#  'wvSgl',
#  '6oOPKx',
#  '9sU3DlO',
#  'sSPIZcaJ',
#  '4tW1zABwq',
#  'TNRyOjaGqA',
#  'J1',
#  'PNR',
#  'K1LS',
#  'mAugw',
#  'EWPxM3',
#  'i0z37WQ',
#  'bKVrEZfx',
#  'sXP5pVUED',
#  'CL9yhIERis',
#  'UB',
#  'qoT',
#  'ysnE',
#  'elrQ2',
#  'tfIAgQ',
#  'hWGVQ2x',
#  'TiJgqtBO',
#  'Nuq7YfR0I',
#  'dA472ay5Mh',
#  'dT',
#  'EOe',
#  'Zn3C',
#  'TQBfP',
#  'CWPekl',
#  'gSs1Dt5',
#  'AVgnjaYC',
#  's3x8Km7QP',
#  '0WwdIiMoyU',
#  'LC']

# %%
def fitness(password, test_word):
    score = 0

    if len(password) != len(test_word):
        return score
    
    # if fit length, I'll give you score 0.5
    len_score = 0.5
    score += len_score

    for i in range(len(password)):
        if password[i] == test_word[i]:
            score += 1

    # 백점 만점에 몇점?
    return score / (len(password) + len_score) * 100

fitness('KimSaYeon', 'KimSaYuon')
# Out:
# 89.47368421052632

# %%
def compute_performace(population, password):
    performance_list = []
    for individual in population:
        score = fitness(password, individual)

        # we can predict length of password
        if score > 0:
            pred_len = len(individual)
        performance_list.append([individual, score])

    population_sorted = sorted(performance_list, key=lambda x: x[1], reverse=True)
    return population_sorted, pred_len

def select_survivors(population_sorted, best_sample, lucky_few, password_len):
    next_generation = []

    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_generation.append(population_sorted[i][0])

    lucky_survivors = random.sample(population_sorted, k=lucky_few)
    for l in lucky_survivors:
        next_generation.append(l[0])
    
    # generate new population if next_generation is too small
    while len(next_generation) < best_sample + lucky_few:
        next_generation.append(generate_word(length=password_len))

    random.shuffle(next_generation)
    return next_generation

pop_sorted, pred_len = compute_performace(pop, password)
survivors = select_survivors(pop_sorted, best_sample=20, lucky_few=20, password_len=pred_len)

print('Password length must be %s' % pred_len)
survivors
# Out:
# Password length must be 9
# ['sXP5pVUED',
#  'OLdGUYuC0',
#  'eZVna4BgN',
#  'DKbmV',
#  'DNHeK9M1a',
#  '36s4k5ehn',
#  'TiJgqtBO',
#  'Yd2ESATQl',
#  'ulCkYMhqs',
#  'DNHeK9M1a',
#  'wG26VNh0b',
#  'CL9yhIERis',
#  'i0z37WQ',
#  '7fAMC8Sy1',
#  's3x8Km7QP',
#  'I9',
#  'lVbxr1BJP',
#  'CGcDh72AK',
#  'b5',
#  'LC',
#  'lVbxr1BJP',
#  '4tW1zABwq',
#  'kAIj',
#  'MinkCU',
#  'RrSq',
#  'm7uNkZ942',
#  'DaNXTsM',
#  'QUtSHmiOw',
#  'K6Gdwz',
#  'kXhoxc5dA',
#  'elrQ2',
#  'sWclS2qUH',
#  '0h9jC4r1W',
#  'Nuq7YfR0I',
#  'dA472ay5Mh',
#  'vRN6LDqiG2',
#  'xX2lB8cKnb',
#  'hUMltE7Jq',
#  '1nj5cm',
#  'rP9c']

# %%
def create_child(individual1, individual2):
    child = ''
    min_len_ind = min(len(individual1), len(individual2))
    for i in range(min_len_ind):
        if (int(100 * random.random()) < 50):
            child += individual1[i]
        else:
            child += individual2[i]
    return child

# 우리는 그렇게 자비롭지 않기때문에 부모를 내 맘대로 짝지어줄 것이다
def create_children(parents, n_child):
    next_population = []
    for i in range(int(len(parents)/2)):
        for j in range(n_child):
            next_population.append(create_child(parents[i], parents[len(parents) - 1 - i]))
    return next_population

children = create_children(survivors, 5)

children
# Out:
# ['rXPc',
#  'sXPc',
#  'sXP5',
#  'sX9c',
#  'rXPc',
#  '1Ld5UY',
#  '1ndGUm',
#  'OLdGcm',
#  'OLdGcY',
#  'OLj5Um',
#  'hZMla4BgN',
#  'eUVna47gN',
#  'eUVltEBJN',
#  'hUVntEBJq',
#  'hUMnaEBgN',
#  'xKblV',
#  'DX2mV',
#  'xKblB',
#  'xX2lB',
#  'xXblB',
#  'vNHeK9q1a',
#  'DNNeKDqiG',
#  'DNH6KDMiG',
#  'DNN6K9qia',
#  'DNHeK9M1a',
#  '36472ae5n',
#  'd6s725yhn',
#  '3As42ay5M',
#  '3644k5e5M',
#  '3As4k5e5M',
#  'Tiq7YfRO',
#  'TuJ7qtB0',
#  'NiJgqfB0',
#  'NiJgqtBO',
#  'Tiq7qtR0',
#  'Yh9jCArQW',
#  'Yd2ECATQl',
#  '0d2ECArQl',
#  'Yh2EC4rQl',
#  'Yh9jS4rQl',
#  'uWCkSMhqs',
#  'slClY2qqH',
#  'ulClS2qqs',
#  'slClS2qqH',
#  'slclSMhUH',
#  'DlHQK',
#  'eNrQ2',
#  'elHQ2',
#  'DlHQK',
#  'eNreK',
#  'kG2oxNhdA',
#  'kG2oxNhdb',
#  'kXh6VN5dA',
#  'wX2oxNh0b',
#  'kXhoxN50A',
#  'CLGyhI',
#  'KL9yhI',
#  'C69yhI',
#  'K6Gdhz',
#  'KLGdhI',
#  'QUzS7mi',
#  'iUtS7WQ',
#  'iUzS7WQ',
#  'Q0tS7WQ',
#  'QUz37mi',
#  'DfNMC8S',
#  'DfAMT8M',
#  '7aAXT8M',
#  '7aAXC8M',
#  'DfAXC8S',
#  'm3u8KZ9QP',
#  's3x8km74P',
#  'm3xNkZ94P',
#  's7xNKm74P',
#  'm3x8Km9Q2',
#  'I9',
#  'I9',
#  'Ir',
#  'Rr',
#  'Rr',
#  'MibxrU',
#  'linxC1',
#  'MinkrU',
#  'MVbxCU',
#  'linkCU',
#  'kGIj',
#  'kGID',
#  'kGIj',
#  'kAcj',
#  'kGcD',
#  '4t',
#  'b5',
#  '45',
#  'bt',
#  '4t',
#  'lC',
#  'lC',
#  'lC',
#  'LV',
#  'LC']

# %%
def mutate_word(word):
    idx = int(random.random() * len(word))
    if (idx == 0):
        word = random.choice(string.ascii_letters + string.digits) + word[1:]
    else:
        word = word[:idx] + random.choice(string.ascii_letters + string.digits) + word[idx+1:]
    return word

def mutate_population(population, chance_of_mutation):
    for i in range(len(population)):
        if random.random() * 100 < chance_of_mutation:
            population[i] = mutate_word(population[i])
    return population

new_generation = mutate_population(population=children, chance_of_mutation=10)

new_generation
# Out:
# ['5XPc',
#  'sXPc',
#  'sBP5',
#  'sX9c',
#  'rXPc',
#  '1Ld5UY',
#  '1ndGUm',
#  'OLdGcm',
#  'OLDGcY',
#  'OLj5Um',
#  'hZMla4BgN',
#  'eUVna47gN',
#  'eUVltEBJN',
#  'hUVntEBJq',
#  'hUMnaEBgN',
#  'xKblV',
#  'DXwmV',
#  'xKblB',
#  'xX2lB',
#  'xXblB',
#  'vNHeK9q1a',
#  'DNNeKDqiG',
#  'DNH6KDMiG',
#  'DNN6K9qia',
#  'DNHeK9M1a',
#  '36472ae5n',
#  'v6s725yhn',
#  '3As42ay5M',
#  '3644k5e5M',
#  '3As4k5e5M',
#  'Tiq7YfRO',
#  'TuJ7qtB0',
#  'NiJgqfB0',
#  'NiJgqtBO',
#  'Tiq7qSR0',
#  'Yh9jCArQW',
#  'Yd2EHATQl',
#  '0d2ECArQl',
#  'Yh2EC4rQl',
#  'Yh9jS4rQl',
#  'uWCkSMhqs',
#  'slClY1qqH',
#  'ulClS2qqs',
#  'slClS2qqH',
#  'slclSMhUH',
#  'DlHQK',
#  'eNrQ2',
#  'elHQ2',
#  'DlHQK',
#  'eNreK',
#  'kG2oxNhdA',
#  'kG2oxNhdb',
#  'kXh6VN5dA',
#  'wX2oxNh0b',
#  'kXhoxN50A',
#  'CLGzhI',
#  'KL9yhI',
#  'C69yhI',
#  'K6Gdhz',
#  'KLGdhI',
#  'QUzS7mi',
#  'iUtS7WQ',
#  'iUzS7WQ',
#  'Q0tS7WQ',
#  'QUz37mi',
#  'DfNMC8S',
#  'DfAMT8M',
#  '7aAXT8M',
#  '7aAXC8M',
#  'DfAXC8S',
#  'm3u8KZ9QP',
#  's3x8km74P',
#  'm3xNkZ94P',
#  's7xNKm74P',
#  'm3x8Km9Q2',
#  'I9',
#  'I9',
#  'Ir',
#  'Rr',
#  'Rr',
#  'MibxrU',
#  'linxC1',
#  'MinkrU',
#  'MVbxCU',
#  'linkCU',
#  'kGIj',
#  'kGID',
#  '7GIj',
#  'kAcj',
#  'kGcD',
#  '4t',
#  'b5',
#  '4p',
#  'bt',
#  '4t',
#  'lC',
#  'lj',
#  'lC',
#  'LV',
#  'LC']

# %%
password = 'KimSaYeon'
n_generation = 300
population = 100
best_sample = 20
lucky_few = 20
n_child = 5
chance_of_mutation = 10

pop = generate_population(size=population, min_len=min_len, max_len=max_len)

for g in range(n_generation):
    pop_sorted, pred_len = compute_performace(population=pop, password=password)

    if int(pop_sorted[0][1]) == 100:
        print('SUCCESS! The password is %s' % (pop_sorted[0][0]))
        break
    
    survivors = select_survivors(population_sorted=pop_sorted, best_sample=best_sample, lucky_few=lucky_few, password_len=pred_len)
    
    children = create_children(parents=survivors, n_child=n_child)

    new_generation = mutate_population(population=children, chance_of_mutation=10)
    
    pop = new_generation
    
    print('===== %sth Generation =====' % (g + 1))
    print(pop_sorted[0])
# Out:
# ===== 1th Generation =====
# ['Hw9SuMOKc', 15.789473684210526]
# ===== 2th Generation =====
# ['ewPSu4vKx', 15.789473684210526]
# ===== 3th Generation =====
# ['HwGSBVN3m', 15.789473684210526]
# ===== 4th Generation =====
# ['bwGSvVvhm', 15.789473684210526]
# ===== 5th Generation =====
# ['ijGSgVNQH', 15.789473684210526]
# ===== 6th Generation =====
# ['HwGSvVNhb', 15.789473684210526]
# ===== 7th Generation =====
# ['bwGSBYv3H', 26.31578947368421]
# ===== 8th Generation =====
# ['bwGSEYNhm', 26.31578947368421]
# ===== 9th Generation =====
# ['bwGSvY83H', 26.31578947368421]
# ===== 10th Generation =====
# ['bwGSvY5rH', 26.31578947368421]
# ===== 11th Generation =====
# ['FwGSEYvfH', 26.31578947368421]
# ===== 12th Generation =====
# ['HwGSvYv3b', 26.31578947368421]
# ===== 13th Generation =====
# ['bcGSEY53H', 26.31578947368421]
# ===== 14th Generation =====
# ['bwGSvYv3b', 26.31578947368421]
# ===== 15th Generation =====
# ['H7GSgY5fQ', 26.31578947368421]
# ===== 16th Generation =====
# ['b5GSgY53b', 26.31578947368421]
# ===== 17th Generation =====
# ['5cGSvY53H', 26.31578947368421]
# ===== 18th Generation =====
# ['bwGSvY5QH', 26.31578947368421]
# ===== 19th Generation =====
# ['bcGSgY5QH', 26.31578947368421]
# ===== 20th Generation =====
# ['b7GSgY5QH', 26.31578947368421]
# ===== 21th Generation =====
# ['bcGSgY5QH', 26.31578947368421]
# ===== 22th Generation =====
# ['bcGSgY5oH', 36.84210526315789]
# ===== 23th Generation =====
# ['bcGSgY5oH', 36.84210526315789]
# ===== 24th Generation =====
# ['bcGSaY5QQ', 36.84210526315789]
# ===== 25th Generation =====
# ['5cGSaY5QH', 36.84210526315789]
# ===== 26th Generation =====
# ['bcGSaY53H', 36.84210526315789]
# ===== 27th Generation =====
# ['bcGSaY5QQ', 36.84210526315789]
# ===== 28th Generation =====
# ['5cGSaY5QH', 36.84210526315789]
# ===== 29th Generation =====
# ['YcGSaY5SO', 36.84210526315789]
# ===== 30th Generation =====
# ['bcGSaY5QQ', 36.84210526315789]
# ===== 31th Generation =====
# ['bcGSaY5QH', 36.84210526315789]
# ===== 32th Generation =====
# ['5cGSaY5QH', 36.84210526315789]
# ===== 33th Generation =====
# ['5cGSaYjQH', 36.84210526315789]
# ===== 34th Generation =====
# ['5cGSaY5QQ', 36.84210526315789]
# ===== 35th Generation =====
# ['5cGSaYyfQ', 36.84210526315789]
# ===== 36th Generation =====
# ['5c0SaY5QH', 36.84210526315789]
# ===== 37th Generation =====
# ['5cSSaY5QH', 36.84210526315789]
# ===== 38th Generation =====
# ['5cGSaY5QQ', 36.84210526315789]
# ===== 39th Generation =====
# ['bcGSaY5QH', 36.84210526315789]
# ===== 40th Generation =====
# ['bcGSaY5QH', 36.84210526315789]
# ===== 41th Generation =====
# ['5cGSaY5QQ', 36.84210526315789]
# ===== 42th Generation =====
# ['5cGSaYgQQ', 36.84210526315789]
# ===== 43th Generation =====
# ['5cVSaYgfn', 47.368421052631575]
# ===== 44th Generation =====
# ['5cVSaYgfn', 47.368421052631575]
# ===== 45th Generation =====
# ['5cVSaYgfn', 47.368421052631575]
# ===== 46th Generation =====
# ['5cVSaYgfn', 47.368421052631575]
# ===== 47th Generation =====
# ['NcGSaYyQn', 47.368421052631575]
# ===== 48th Generation =====
# ['5cGSaYyQn', 47.368421052631575]
# ===== 49th Generation =====
# ['5cVSaYgQn', 47.368421052631575]
# ===== 50th Generation =====
# ['5XVSaYgQn', 47.368421052631575]
# ===== 51th Generation =====
# ['5cVSaYyQn', 47.368421052631575]
# ===== 52th Generation =====
# ['5cGSaYgQn', 47.368421052631575]
# ===== 53th Generation =====
# ['5jVSaYyfn', 47.368421052631575]
# ===== 54th Generation =====
# ['5cVSaYyfn', 47.368421052631575]
# ===== 55th Generation =====
# ['5cVSaYgon', 57.89473684210527]
# ===== 56th Generation =====
# ['5cVSaYgon', 57.89473684210527]
# ===== 57th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 58th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 59th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 60th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 61th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 62th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 63th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 64th Generation =====
# ['5UGSaYyon', 57.89473684210527]
# ===== 65th Generation =====
# ['5cmSaYyon', 68.42105263157895]
# ===== 66th Generation =====
# ['55VSaYyon', 57.89473684210527]
# ===== 67th Generation =====
# ['JcGSaYyon', 57.89473684210527]
# ===== 68th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 69th Generation =====
# ['5UGSaYyon', 57.89473684210527]
# ===== 70th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 71th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 72th Generation =====
# ['5OVSaYyon', 57.89473684210527]
# ===== 73th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 74th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 75th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 76th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 77th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 78th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 79th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 80th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 81th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 82th Generation =====
# ['5cVSaYyon', 57.89473684210527]
# ===== 83th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 84th Generation =====
# ['5cGSaYyon', 57.89473684210527]
# ===== 85th Generation =====
# ['KcGSaYyon', 68.42105263157895]
# ===== 86th Generation =====
# ['KcKSaYyon', 68.42105263157895]
# ===== 87th Generation =====
# ['KMGSaYyon', 68.42105263157895]
# ===== 88th Generation =====
# ['KMVSaYEon', 68.42105263157895]
# ===== 89th Generation =====
# ['KcVSaYyon', 68.42105263157895]
# ===== 90th Generation =====
# ['KcGSaYlon', 68.42105263157895]
# ===== 91th Generation =====
# ['KiuSaYlon', 78.94736842105263]
# ===== 92th Generation =====
# ['KiGSaYlon', 78.94736842105263]
# ===== 93th Generation =====
# ['KiuSaYyon', 78.94736842105263]
# ===== 94th Generation =====
# ['KiuSaYlon', 78.94736842105263]
# ===== 95th Generation =====
# ['KiuSaY4on', 78.94736842105263]
# ===== 96th Generation =====
# ['KiGSaYlon', 78.94736842105263]
# ===== 97th Generation =====
# ['KiuSaYyon', 78.94736842105263]
# ===== 98th Generation =====
# ['KiuSaYyon', 78.94736842105263]
# ===== 99th Generation =====
# ['KiuSaYyon', 78.94736842105263]
# ===== 100th Generation =====
# ['KiVSaY1on', 78.94736842105263]
# ===== 101th Generation =====
# ['KiGSaYlon', 78.94736842105263]
# ===== 102th Generation =====
# ['KiuSaYlon', 78.94736842105263]
# ===== 103th Generation =====
# ['KiuSaY4on', 78.94736842105263]
# ===== 104th Generation =====
# ['KiuSaYlon', 78.94736842105263]
# ===== 105th Generation =====
# ['KiuSaYlon', 78.94736842105263]
# ===== 106th Generation =====
# ['KiHSaYyon', 78.94736842105263]
# ===== 107th Generation =====
# ['KiuSaY4on', 78.94736842105263]
# ===== 108th Generation =====
# ['Ki2SaYyon', 78.94736842105263]
# ===== 109th Generation =====
# ['KiuSaYson', 78.94736842105263]
# ===== 110th Generation =====
# ['KiuSaYyon', 78.94736842105263]
# ===== 111th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 112th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 113th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 114th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 115th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 116th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 117th Generation =====
# ['KiDSaYeon', 89.47368421052632]
# ===== 118th Generation =====
# ['Ki2SaYeon', 89.47368421052632]
# ===== 119th Generation =====
# ['Ki2SaYeon', 89.47368421052632]
# ===== 120th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 121th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 122th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 123th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 124th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 125th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 126th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 127th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 128th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 129th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 130th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 131th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 132th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 133th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 134th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 135th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 136th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 137th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 138th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 139th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 140th Generation =====
# ['KiuSaYeon', 89.47368421052632]
# ===== 141th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 142th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 143th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 144th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 145th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 146th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 147th Generation =====
# ['KilSaYeon', 89.47368421052632]
# ===== 148th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 149th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 150th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 151th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 152th Generation =====
# ['KilSaYeon', 89.47368421052632]
# ===== 153th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 154th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 155th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 156th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 157th Generation =====
# ['KiJSaYeon', 89.47368421052632]
# ===== 158th Generation =====
# ['KioSaYeon', 89.47368421052632]
# ===== 159th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 160th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 161th Generation =====
# ['KioSaYeon', 89.47368421052632]
# ===== 162th Generation =====
# ['Ki1SaYeon', 89.47368421052632]
# ===== 163th Generation =====
# ['Ki1SaYeon', 89.47368421052632]
# ===== 164th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 165th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 166th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 167th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 168th Generation =====
# ['KiTSaYeon', 89.47368421052632]
# ===== 169th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 170th Generation =====
# ['KioSaYeon', 89.47368421052632]
# ===== 171th Generation =====
# ['KiTSaYeon', 89.47368421052632]
# ===== 172th Generation =====
# ['KiTSaYeon', 89.47368421052632]
# ===== 173th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 174th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 175th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 176th Generation =====
# ['KiNSaYeon', 89.47368421052632]
# ===== 177th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 178th Generation =====
# ['KiNSaYeon', 89.47368421052632]
# ===== 179th Generation =====
# ['KiTSaYeon', 89.47368421052632]
# ===== 180th Generation =====
# ['KiTSaYeon', 89.47368421052632]
# ===== 181th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 182th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 183th Generation =====
# ['KiUSaYeon', 89.47368421052632]
# ===== 184th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 185th Generation =====
# ['KiTSaYeon', 89.47368421052632]
# ===== 186th Generation =====
# ['KiNSaYeon', 89.47368421052632]
# ===== 187th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 188th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 189th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 190th Generation =====
# ['KiNSaYeon', 89.47368421052632]
# ===== 191th Generation =====
# ['KiTSaYeon', 89.47368421052632]
# ===== 192th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 193th Generation =====
# ['KigSaYeon', 89.47368421052632]
# ===== 194th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 195th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 196th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 197th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 198th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 199th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 200th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 201th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 202th Generation =====
# ['KikSaYeon', 89.47368421052632]
# ===== 203th Generation =====
# ['KikSaYeon', 89.47368421052632]
# SUCCESS! The password is KimSaYeon
